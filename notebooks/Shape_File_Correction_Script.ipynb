# %%
path1 = "/home/student/610_production_code/mongo-project-flocknroll/dataset/state_boundaries_with_center/states.shp"
path2 = "/home/student/610_production_code/mongo-project-flocknroll/dataset/states_boundaries_lowest_res/cb_2018_us_state_20m.shp"

# %%
import pandas as pd
import geopandas as gpd

# %%
old_df = gpd.read_file(path1)

# %%
new_df = gpd.read_file(path2)

# %%
new_df['center'] = old_df['center']

# %%
new_df = new_df[['STATEFP', 'STATENS', 'AFFGEOID', 'GEOID', 'STUSPS', 'NAME', 'LSAD',
       'ALAND', 'AWATER', 'center', 'geometry']]

# %%
new_df
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS                  NAME LSAD  \
# 0       24  01714934  0400000US24    24     MD              Maryland   00
# 1       19  01779785  0400000US19    19     IA                  Iowa   00
# 2       10  01779781  0400000US10    10     DE              Delaware   00
# 3       39  01085497  0400000US39    39     OH                  Ohio   00
# 4       42  01779798  0400000US42    42     PA          Pennsylvania   00
# 5       31  01779792  0400000US31    31     NE              Nebraska   00
# 6       53  01779804  0400000US53    53     WA            Washington   00
# 7       72  01779808  0400000US72    72     PR           Puerto Rico   00
# 8       01  01779775  0400000US01    01     AL               Alabama   00
# 9       05  00068085  0400000US05    05     AR              Arkansas   00
# 10      35  00897535  0400000US35    35     NM            New Mexico   00
# 11      48  01779801  0400000US48    48     TX                 Texas   00
# ...

# %%
newdf_geo = gpd.GeoDataFrame(new_df, geometry='geometry')

# %%
newdf_geo.to_file('states.shp', driver='ESRI Shapefile')
